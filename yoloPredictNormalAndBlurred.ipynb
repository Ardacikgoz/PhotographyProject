# %%
# !pip install ultralytics

import os
os.environ["ULTRALYTICS_SETTINGS"] = "0"

from ultralytics import YOLO
model = YOLO('yolov8n.pt')
# Out:
# ...
#
# [notice] A new release of pip is available: 25.0 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
metrics = model.val(
    data='data.yaml',
    imgsz=640,
    batch=16,
    cache=False,
    save_json=False
)
# Out:
# Ultralytics 8.3.67 🚀 Python-3.12.4 torch-2.5.1 CPU (Apple M1)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
# val: Scanning /Users/ardaacikgoz/Desktop/Cs/ThirdYear/AIN434- PHOTOGRAPHY/Projec
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1000       7204      0.636      0.478      0.539       0.39
#                 person        546       2251      0.775      0.658      0.729      0.504
#                bicycle         33         78      0.658      0.269      0.357      0.188
#                    car         98        347       0.65      0.513      0.553      0.353
#             motorcycle         26         62      0.729      0.774      0.817      0.521
#               airplane         20         26      0.858      0.731      0.794       0.66
#                    bus         32         57      0.824      0.577       0.72      0.582
# ...

# %%
yaml_content = """
path: .
train: newBlurImages/Bilateral Filtered
val: newBlurImages/Bilateral Filtered
test: newBlurImages/Bilateral Filtered

names:
  0: person
  1: bicycle
  2: car
  3: motorcycle
  4: airplane
  5: bus
  6: train
  7: truck
  8: boat
  9: traffic light
  10: fire hydrant
  11: stop sign
  12: parking meter
  13: bench
  14: bird
  15: cat
  16: dog
  17: horse
  18: sheep
  19: cow
  20: elephant
  21: bear
  22: zebra
  23: giraffe
  24: backpack
  25: umbrella
  26: handbag
  27: tie
  28: suitcase
  29: frisbee
  30: skis
  31: snowboard
  32: sports ball
  33: kite
  34: baseball bat
  35: baseball glove
  36: skateboard
  37: surfboard
  38: tennis racket
  39: bottle
  40: wine glass
  41: cup
  42: fork
  43: knife
  44: spoon
  45: bowl
  46: banana
  47: apple
  48: sandwich
  49: orange
  50: broccoli
  51: carrot
  52: hot dog
  53: pizza
  54: donut
  55: cake
  56: chair
  57: couch
  58: potted plant
  59: bed
  60: dining table
  61: toilet
  62: tv
  63: laptop
  64: mouse
  65: remote
  66: keyboard
  67: cell phone
  68: microwave
  69: oven
  70: toaster
  71: sink
  72: refrigerator
  73: book
  74: clock
  75: vase
  76: scissors
  77: teddy bear
  78: hair drier
  79: toothbrush
"""

with open('bluredBileteral.yaml', 'w') as f:
    f.write(yaml_content)

# %%
metrics_blurred = model.val(
    data='bluredBileteral.yaml',
    imgsz=640,
    batch=16,
    cache=False,
    save_json=False
)
# Out:
# Ultralytics 8.3.67 🚀 Python-3.12.4 torch-2.5.1 CPU (Apple M1)
# val: Scanning /Users/ardaacikgoz/Desktop/Cs/ThirdYear/AIN434- PHOTOGRAPHY/Projec
# val: New cache created: /Users/ardaacikgoz/Desktop/Cs/ThirdYear/AIN434- PHOTOGRAPHY/Project/datasets/newBlurImages/Bilateral Filtered/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1000       7204      0.486       0.34      0.356      0.245
#                 person        546       2251      0.646      0.527      0.573       0.37
#                bicycle         33         78      0.642     0.0694      0.155     0.0851
#                    car         98        347      0.503      0.383      0.371      0.231
#             motorcycle         26         62      0.491      0.581      0.561      0.319
#               airplane         20         26      0.559      0.654      0.703       0.57
# ...

# %%
def update_yaml_paths(yaml_text, new_path):
    updated_lines = []
    for line in yaml_text.splitlines():
        if line.strip().startswith(("train:", "val:", "test:")):
            key = line.split(":")[0]
            updated_line = f"{key}: {new_path}"
            updated_lines.append(updated_line)
        else:
            updated_lines.append(line)
    return "\n".join(updated_lines)

# %%
blurDefocus_Blurred = update_yaml_paths(yaml_content,"newBlurImages/Defocus Blurred")
with open("blurDefocus_Blurred.yaml", "w") as f:
    f.write(blurDefocus_Blurred)

metrics_blurred = model.val(
    data='blurDefocus_Blurred.yaml',
    imgsz=640,
    batch=16,
    cache=False,
    save_json=False
)
# Out:
# Ultralytics 8.3.67 🚀 Python-3.12.4 torch-2.5.1 CPU (Apple M1)
# val: Scanning /Users/ardaacikgoz/Desktop/Cs/ThirdYear/AIN434- PHOTOGRAPHY/Projec
# val: New cache created: /Users/ardaacikgoz/Desktop/Cs/ThirdYear/AIN434- PHOTOGRAPHY/Project/datasets/newBlurImages/Defocus Blurred/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1000       7204      0.546      0.342      0.378      0.255
#                 person        546       2251      0.726      0.505      0.582      0.373
#                bicycle         33         78      0.627      0.151      0.175       0.08
#                    car         98        347      0.598      0.303      0.353       0.21
#             motorcycle         26         62      0.599      0.565      0.604      0.319
#               airplane         20         26      0.758      0.615      0.687       0.53
# ...

# %%
blurGaussian = update_yaml_paths(yaml_content,"newBlurImages/Gaussian Blurred")
with open("blurGaussian.yaml", "w") as f:
    f.write(blurGaussian)

metrics_blurred = model.val(
    data='blurGaussian.yaml',
    imgsz=640,
    batch=16,
    cache=False,
    save_json=False
)
# Out:
# Ultralytics 8.3.67 🚀 Python-3.12.4 torch-2.5.1 CPU (Apple M1)
# val: Scanning /Users/ardaacikgoz/Desktop/Cs/ThirdYear/AIN434- PHOTOGRAPHY/Projec
# val: New cache created: /Users/ardaacikgoz/Desktop/Cs/ThirdYear/AIN434- PHOTOGRAPHY/Project/datasets/newBlurImages/Gaussian Blurred/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1000       7204      0.409      0.251      0.257      0.173
#                 person        546       2251      0.608      0.429      0.467       0.29
#                bicycle         33         78      0.235     0.0256     0.0394     0.0201
#                    car         98        347      0.417      0.225      0.219      0.131
#             motorcycle         26         62      0.396      0.339      0.327      0.167
#               airplane         20         26      0.484      0.468      0.496      0.374
# ...

# %%
blurLow_Light = update_yaml_paths(yaml_content,"newBlurImages/Low Light Blurred")
with open("blurLow_Light.yaml", "w") as f:
    f.write(blurLow_Light)

metrics_blurred = model.val(
    data='blurLow_Light.yaml',
    imgsz=640,
    batch=16,
    cache=False,
    save_json=False
)
# Out:
# Ultralytics 8.3.67 🚀 Python-3.12.4 torch-2.5.1 CPU (Apple M1)
# val: Scanning /Users/ardaacikgoz/Desktop/Cs/ThirdYear/AIN434- PHOTOGRAPHY/Projec
# val: New cache created: /Users/ardaacikgoz/Desktop/Cs/ThirdYear/AIN434- PHOTOGRAPHY/Project/datasets/newBlurImages/Low Light Blurred/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1000       7204       0.25      0.059     0.0484     0.0294
#                 person        546       2251      0.372       0.14      0.144     0.0761
#                bicycle         33         78          1          0          0          0
#                    car         98        347      0.199     0.0259     0.0222     0.0129
#             motorcycle         26         62          1          0    0.00295   0.000884
#               airplane         20         26      0.135     0.0769     0.0855     0.0348
# ...

# %%
blurMotion = update_yaml_paths(yaml_content,"newBlurImages/Motion Blurred")
with open("blurMotion.yaml", "w") as f:
    f.write(blurMotion)

metrics_blurred = model.val(
    data='blurMotion.yaml',
    imgsz=640,
    batch=16,
    cache=False,
    save_json=False
)
# Out:
# Ultralytics 8.3.67 🚀 Python-3.12.4 torch-2.5.1 CPU (Apple M1)
# val: Scanning /Users/ardaacikgoz/Desktop/Cs/ThirdYear/AIN434- PHOTOGRAPHY/Projec
# val: New cache created: /Users/ardaacikgoz/Desktop/Cs/ThirdYear/AIN434- PHOTOGRAPHY/Project/datasets/newBlurImages/Motion Blurred/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1000       7204        0.3       0.13      0.132     0.0829
#                 person        546       2251      0.373      0.346      0.316      0.178
#                bicycle         33         78     0.0455     0.0897     0.0188    0.00762
#                    car         98        347      0.189      0.176      0.121     0.0636
#             motorcycle         26         62     0.0975      0.177     0.0967     0.0349
#               airplane         20         26      0.386      0.577      0.549      0.397
# ...

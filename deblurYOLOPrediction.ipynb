# %%
# !pip install ultralytics

import os
os.environ["ULTRALYTICS_SETTINGS"] = "0"

from ultralytics import YOLO
model = YOLO('yolov8n.pt')
# Out:
# ...
#
# [notice] A new release of pip is available: 25.0 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
yaml_content = """
path: .
train: deblurRL/Bilateral_Filtered
val: deblurRL/Bilateral_Filtered
test: deblurRL/Bilateral_Filtered

names:
  0: person
  1: bicycle
  2: car
  3: motorcycle
  4: airplane
  5: bus
  6: train
  7: truck
  8: boat
  9: traffic light
  10: fire hydrant
  11: stop sign
  12: parking meter
  13: bench
  14: bird
  15: cat
  16: dog
  17: horse
  18: sheep
  19: cow
  20: elephant
  21: bear
  22: zebra
  23: giraffe
  24: backpack
  25: umbrella
  26: handbag
  27: tie
  28: suitcase
  29: frisbee
  30: skis
  31: snowboard
  32: sports ball
  33: kite
  34: baseball bat
  35: baseball glove
  36: skateboard
  37: surfboard
  38: tennis racket
  39: bottle
  40: wine glass
  41: cup
  42: fork
  43: knife
  44: spoon
  45: bowl
  46: banana
  47: apple
  48: sandwich
  49: orange
  50: broccoli
  51: carrot
  52: hot dog
  53: pizza
  54: donut
  55: cake
  56: chair
  57: couch
  58: potted plant
  59: bed
  60: dining table
  61: toilet
  62: tv
  63: laptop
  64: mouse
  65: remote
  66: keyboard
  67: cell phone
  68: microwave
  69: oven
  70: toaster
  71: sink
  72: refrigerator
  73: book
  74: clock
  75: vase
  76: scissors
  77: teddy bear
  78: hair drier
  79: toothbrush
"""

with open('rlBilateral.yaml', 'w') as f:
    f.write(yaml_content)

# %%
metrics_blurred = model.val(
    data='rlBilateral.yaml',
    imgsz=640,
    batch=16,
    cache=False,
    save_json=False
)
# Out:
# Ultralytics 8.3.67 🚀 Python-3.12.4 torch-2.5.1 CPU (Apple M1)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
# val: Scanning /Users/ardaacikgoz/Desktop/Cs/ThirdYear/AIN434- PHOTOGRAPHY/Projec
# val: New cache created: /Users/ardaacikgoz/Desktop/Cs/ThirdYear/AIN434- PHOTOGRAPHY/Project/datasets/deblurRL/Bilateral_Filtered/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1000       7204      0.438      0.222      0.234      0.152
#                 person        546       2251      0.617        0.4      0.448      0.258
#                bicycle         33         78      0.266     0.0769     0.0619     0.0331
#                    car         98        347      0.387      0.314      0.255      0.141
#             motorcycle         26         62      0.502      0.373        0.4      0.195
# ...

# %%
def update_yaml_paths(yaml_text, new_path):
    updated_lines = []
    for line in yaml_text.splitlines():
        if line.strip().startswith(("train:", "val:", "test:")):
            key = line.split(":")[0]
            updated_line = f"{key}: {new_path}"
            updated_lines.append(updated_line)
        else:
            updated_lines.append(line)
    return "\n".join(updated_lines)

# %%
rlDefocus_Blurred = update_yaml_paths(yaml_content,"deblurRL/Defocus_Blurred")
with open("rlDefocus_Blurred.yaml", "w") as f:
    f.write(rlDefocus_Blurred)

# %%
metrics_blurred = model.val(
    data='rlDefocus_Blurred.yaml',
    imgsz=640,
    batch=16,
    cache=False,
    save_json=False
)
# Out:
# Ultralytics 8.3.67 🚀 Python-3.12.4 torch-2.5.1 CPU (Apple M1)
# val: Scanning /Users/ardaacikgoz/Desktop/Cs/ThirdYear/AIN434- PHOTOGRAPHY/Projec
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1000       7204      0.437      0.281      0.289      0.191
#                 person        546       2251      0.612      0.486       0.52       0.32
#                bicycle         33         78      0.403      0.167      0.124      0.054
#                    car         98        347      0.462      0.259      0.276      0.164
#             motorcycle         26         62      0.656      0.323      0.444      0.266
#               airplane         20         26      0.578      0.462      0.534      0.362
#                    bus         32         57      0.517      0.386      0.423      0.324
#                  train         31         36      0.285      0.556      0.499      0.375
# ...

# %%
rlGaussian = update_yaml_paths(yaml_content,"deblurRL/Gaussian_Blurred")
with open("rlGaussian.yaml", "w") as f:
    f.write(rlGaussian)

# %%
metrics_blurred = model.val(
    data='rlGaussian.yaml',
    imgsz=640,
    batch=16,
    cache=False,
    save_json=False
)
# Out:
# Ultralytics 8.3.67 🚀 Python-3.12.4 torch-2.5.1 CPU (Apple M1)
# val: Scanning /Users/ardaacikgoz/Desktop/Cs/ThirdYear/AIN434- PHOTOGRAPHY/Projec
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1000       7204      0.436      0.248      0.259      0.169
#                 person        546       2251      0.626      0.412      0.467      0.277
#                bicycle         33         78      0.184     0.0513     0.0492     0.0208
#                    car         98        347      0.478      0.219      0.215      0.116
#             motorcycle         26         62      0.665       0.32      0.401      0.195
#               airplane         20         26      0.548      0.462      0.487      0.349
#                    bus         32         57      0.602      0.368      0.372      0.302
#                  train         31         36      0.419      0.583      0.521      0.389
# ...

# %%
rlLowLight = update_yaml_paths(yaml_content,"deblurRL/Low_Light_Blurred")
with open("rlLowLight.yaml", "w") as f:
    f.write(rlLowLight)

# %%
metrics_blurred = model.val(
    data='rlLowLight.yaml',
    imgsz=640,
    batch=16,
    cache=False,
    save_json=False
)
# Out:
# Ultralytics 8.3.67 🚀 Python-3.12.4 torch-2.5.1 CPU (Apple M1)
# val: Scanning /Users/ardaacikgoz/Desktop/Cs/ThirdYear/AIN434- PHOTOGRAPHY/Projec
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1000       7204       0.01     0.0697    0.00985    0.00527
#                 person        546       2251     0.0216      0.222     0.0358     0.0165
#                bicycle         33         78          0          0          0          0
#                    car         98        347    0.00454     0.0519    0.00323    0.00156
#             motorcycle         26         62     0.0256     0.0161      0.013    0.00391
#               airplane         20         26     0.0123      0.154     0.0263    0.00868
#                    bus         32         57     0.0112     0.0175    0.00603    0.00483
#                  train         31         36      0.011     0.0833    0.00737    0.00275
# ...

# %%
rlMotion_Blurred = update_yaml_paths(yaml_content,"deblurRL/Motion_Blurred")
with open("rlMotion_Blurred.yaml", "w") as f:
    f.write(rlMotion_Blurred)

# %%
metrics_blurred = model.val(
    data='rlMotion_Blurred.yaml',
    imgsz=640,
    batch=16,
    cache=False,
    save_json=False
)
# Out:
# Ultralytics 8.3.67 🚀 Python-3.12.4 torch-2.5.1 CPU (Apple M1)
# val: Scanning /Users/ardaacikgoz/Desktop/Cs/ThirdYear/AIN434- PHOTOGRAPHY/Projec
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1000       7204      0.336     0.0279     0.0395      0.024
#                 person        546       2251      0.289      0.208      0.172      0.086
#                bicycle         33         78     0.0331     0.0256     0.0036    0.00199
#                    car         98        347      0.104     0.0202     0.0193     0.0101
#             motorcycle         26         62      0.149     0.0323     0.0328      0.011
#               airplane         20         26      0.316     0.0769      0.106     0.0677
#                    bus         32         57      0.158      0.175       0.11     0.0876
#                  train         31         36      0.028      0.222     0.0516      0.036
# ...

# %% [markdown]
# # Wiener

# %%
wienerBilateral_Filtered = update_yaml_paths(yaml_content,"deblurWiener/Bilateral_Filtered")
with open("wienerBilateral_Filtered.yaml", "w") as f:
    f.write(wienerBilateral_Filtered)

# %%
metrics_blurred = model.val(
    data='wienerBilateral_Filtered.yaml',
    imgsz=640,
    batch=16,
    cache=False,
    save_json=False
)
# Out:
# Ultralytics 8.3.67 🚀 Python-3.12.4 torch-2.5.1 CPU (Apple M1)
# val: Scanning /Users/ardaacikgoz/Desktop/Cs/ThirdYear/AIN434- PHOTOGRAPHY/Projec
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1000       7204      0.405      0.246      0.253      0.168
#                 person        546       2251       0.58      0.422       0.46      0.284
#                bicycle         33         78      0.143     0.0256     0.0495     0.0292
#                    car         98        347      0.419      0.231      0.223      0.126
#             motorcycle         26         62      0.438      0.355      0.321      0.159
#               airplane         20         26      0.508      0.462      0.507      0.369
#                    bus         32         57      0.569      0.333      0.363        0.3
#                  train         31         36       0.43      0.417      0.486      0.353
# ...

# %%
wienerDefocus_Blurred = update_yaml_paths(yaml_content,"deblurWiener/Defocus_Blurred")
with open("wienerDefocus_Blurred.yaml", "w") as f:
    f.write(wienerDefocus_Blurred)

# %%
metrics_blurred = model.val(
    data='wienerDefocus_Blurred.yaml',
    imgsz=640,
    batch=16,
    cache=False,
    save_json=False
)
# Out:
# Ultralytics 8.3.67 🚀 Python-3.12.4 torch-2.5.1 CPU (Apple M1)
# val: Scanning /Users/ardaacikgoz/Desktop/Cs/ThirdYear/AIN434- PHOTOGRAPHY/Projec
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1000       7204      0.457      0.266      0.284      0.191
#                 person        546       2251       0.65      0.427      0.482      0.301
#                bicycle         33         78       0.21     0.0385      0.071      0.035
#                    car         98        347       0.57      0.228      0.251      0.148
#             motorcycle         26         62       0.44      0.355      0.376      0.182
#               airplane         20         26      0.576        0.5      0.555      0.426
#                    bus         32         57      0.576      0.368      0.392      0.326
#                  train         31         36      0.561      0.472      0.509      0.373
# ...

# %%
wienerGaussian_Blurred = update_yaml_paths(yaml_content,"deblurWiener/Gaussian_Blurred")
with open("wienerGaussian_Blurred.yaml", "w") as f:
    f.write(wienerGaussian_Blurred)

# %%
metrics_blurred = model.val(
    data='wienerGaussian_Blurred.yaml',
    imgsz=640,
    batch=16,
    cache=False,
    save_json=False
)
# Out:
# Ultralytics 8.3.67 🚀 Python-3.12.4 torch-2.5.1 CPU (Apple M1)
# val: Scanning /Users/ardaacikgoz/Desktop/Cs/ThirdYear/AIN434- PHOTOGRAPHY/Projec
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1000       7204      0.357      0.188      0.196      0.128
#                 person        546       2251      0.542      0.369      0.401      0.242
#                bicycle         33         78          0          0     0.0139    0.00646
#                    car         98        347      0.348      0.179      0.156     0.0887
#             motorcycle         26         62      0.418      0.177      0.204     0.0997
#               airplane         20         26      0.413      0.346      0.399      0.332
#                    bus         32         57      0.539      0.281      0.313      0.251
#                  train         31         36      0.327      0.389      0.367      0.248
# ...

# %%
wienerLow_Light_Blurred = update_yaml_paths(yaml_content,"deblurWiener/Low_Light_Blurred")
with open("wienerLow_Light_Blurred.yaml", "w") as f:
    f.write(wienerLow_Light_Blurred)

metrics_blurred = model.val(
    data='wienerLow_Light_Blurred.yaml',
    imgsz=640,
    batch=16,
    cache=False,
    save_json=False
)
# Out:
# Ultralytics 8.3.67 🚀 Python-3.12.4 torch-2.5.1 CPU (Apple M1)
# val: Scanning /Users/ardaacikgoz/Desktop/Cs/ThirdYear/AIN434- PHOTOGRAPHY/Projec
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1000       7204      0.303      0.132      0.113     0.0702
#                 person        546       2251      0.421      0.262      0.263      0.149
#                bicycle         33         78          1          0          0          0
#                    car         98        347      0.334     0.0807     0.0842     0.0481
#             motorcycle         26         62      0.235     0.0161     0.0559     0.0312
#               airplane         20         26      0.368      0.385      0.293      0.196
#                    bus         32         57      0.663      0.172      0.219      0.177
#                  train         31         36      0.361      0.252      0.222      0.142
# ...

# %%
wienerMotion_Blurred = update_yaml_paths(yaml_content,"deblurWiener/Motion_Blurred")
with open("wienerMotion_Blurred.yaml", "w") as f:
    f.write(wienerMotion_Blurred)

metrics_blurred = model.val(
    data='wienerMotion_Blurred.yaml',
    imgsz=640,
    batch=16,
    cache=False,
    save_json=False
)
# Out:
# Ultralytics 8.3.67 🚀 Python-3.12.4 torch-2.5.1 CPU (Apple M1)
# val: Scanning /Users/ardaacikgoz/Desktop/Cs/ThirdYear/AIN434- PHOTOGRAPHY/Projec
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1000       7204      0.333      0.186      0.178       0.11
#                 person        546       2251      0.521       0.32      0.331      0.191
#                bicycle         33         78          0          0     0.0125    0.00483
#                    car         98        347        0.3      0.176      0.143     0.0678
#             motorcycle         26         62      0.364      0.161      0.155     0.0754
#               airplane         20         26      0.336        0.5      0.503      0.353
#                    bus         32         57      0.395      0.316      0.262      0.206
#                  train         31         36      0.278        0.5      0.398      0.297
# ...

# %% [markdown]
# # mrpNet

# %%
mprNetBilateral_Filtered = update_yaml_paths(yaml_content,"mprNet/Bilateral_Filtered")
with open("mprNetBilateral_Filtered.yaml", "w") as f:
    f.write(mprNetBilateral_Filtered)

metrics_blurred = model.val(
    data='mprNetBilateral_Filtered.yaml',
    imgsz=640,
    batch=16,
    cache=False,
    save_json=False
)
# Out:
# Ultralytics 8.3.67 🚀 Python-3.12.4 torch-2.5.1 CPU (Apple M1)
# val: Scanning /Users/ardaacikgoz/Desktop/Cs/ThirdYear/AIN434- PHOTOGRAPHY/Projec
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1000       7204      0.509      0.315      0.346      0.232
#                 person        546       2251      0.715      0.494      0.564      0.354
#                bicycle         33         78      0.536     0.0769      0.131     0.0656
#                    car         98        347      0.495      0.305       0.34      0.191
#             motorcycle         26         62      0.574      0.532      0.519      0.276
#               airplane         20         26      0.573      0.577      0.702      0.526
#                    bus         32         57      0.755      0.439      0.553      0.432
#                  train         31         36      0.559      0.583      0.593      0.414
# ...

# %%
mprNetDefocus_Blurred = update_yaml_paths(yaml_content,"mprNet/Defocus_Blurred")
with open("mprNetDefocus_Blurred.yaml", "w") as f:
    f.write(mprNetDefocus_Blurred)

metrics_blurred = model.val(
    data='mprNetDefocus_Blurred.yaml',
    imgsz=640,
    batch=16,
    cache=False,
    save_json=False
)
# Out:
# Ultralytics 8.3.67 🚀 Python-3.12.4 torch-2.5.1 CPU (Apple M1)
# val: Scanning /Users/ardaacikgoz/Desktop/Cs/ThirdYear/AIN434- PHOTOGRAPHY/Projec
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1000       7204      0.538      0.369      0.397      0.268
#                 person        546       2251        0.7      0.519      0.578      0.374
#                bicycle         33         78      0.724      0.192      0.211      0.116
#                    car         98        347      0.551      0.317       0.34      0.199
#             motorcycle         26         62      0.703      0.581      0.615      0.349
#               airplane         20         26       0.67      0.692      0.758      0.564
#                    bus         32         57      0.658      0.474      0.503      0.414
#                  train         31         36      0.668      0.615      0.666      0.493
# ...

# %%
mprNetGaussian_Blurred = update_yaml_paths(yaml_content,"mprNet/Gaussian_Blurred")
with open("mprNetGaussian_Blurred.yaml", "w") as f:
    f.write(mprNetGaussian_Blurred)

metrics_blurred = model.val(
    data='mprNetGaussian_Blurred.yaml',
    imgsz=640,
    batch=16,
    cache=False,
    save_json=False
)
# Out:
# Ultralytics 8.3.67 🚀 Python-3.12.4 torch-2.5.1 CPU (Apple M1)
# val: Scanning /Users/ardaacikgoz/Desktop/Cs/ThirdYear/AIN434- PHOTOGRAPHY/Projec
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1000       7204      0.452       0.29      0.298      0.198
#                 person        546       2251      0.617      0.442      0.487      0.305
#                bicycle         33         78      0.391     0.0897     0.0922     0.0478
#                    car         98        347      0.479      0.233      0.246      0.138
#             motorcycle         26         62      0.505      0.371      0.389      0.191
#               airplane         20         26      0.536      0.538      0.536      0.422
#                    bus         32         57      0.592      0.368      0.408      0.343
#                  train         31         36      0.617      0.611      0.587      0.412
# ...

# %%
mprNetLow_Light_Blurred = update_yaml_paths(yaml_content,"mprNet/Low_Light_Blurred")
with open("mprNetLow_Light_Blurred.yaml", "w") as f:
    f.write(mprNetLow_Light_Blurred)

metrics_blurred = model.val(
    data='mprNetLow_Light_Blurred.yaml',
    imgsz=640,
    batch=16,
    cache=False,
    save_json=False
)
# Out:
# Ultralytics 8.3.67 🚀 Python-3.12.4 torch-2.5.1 CPU (Apple M1)
# val: Scanning /Users/ardaacikgoz/Desktop/Cs/ThirdYear/AIN434- PHOTOGRAPHY/Projec
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1000       7204     0.0102     0.0197    0.00675    0.00198
#                 person        546       2251    0.00349     0.0315    0.00689    0.00503
#                bicycle         33         78          0          0          0          0
#                    car         98        347    0.00108    0.00865   0.000556    0.00031
#             motorcycle         26         62          0          0          0          0
#               airplane         20         26     0.0152      0.115     0.0165     0.0113
#                    bus         32         57          0          0          0          0
#                  train         31         36    0.00526     0.0278    0.00309   0.000309
# ...

# %%
mprNetMotion_Blurred = update_yaml_paths(yaml_content,"mprNet/Motion_Blurred")
with open("mprNetMotion_Blurred.yaml", "w") as f:
    f.write(mprNetMotion_Blurred)

metrics_blurred = model.val(
    data='mprNetMotion_Blurred.yaml',
    imgsz=640,
    batch=16,
    cache=False,
    save_json=False
)
# Out:
# Ultralytics 8.3.67 🚀 Python-3.12.4 torch-2.5.1 CPU (Apple M1)
# val: Scanning /Users/ardaacikgoz/Desktop/Cs/ThirdYear/AIN434- PHOTOGRAPHY/Projec
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1000       7204      0.523      0.276      0.317      0.209
#                 person        546       2251       0.66      0.467      0.516      0.321
#                bicycle         33         78      0.248     0.0897     0.0815     0.0441
#                    car         98        347      0.461      0.308      0.301      0.172
#             motorcycle         26         62      0.438      0.371      0.387      0.224
#               airplane         20         26      0.508      0.731      0.711        0.5
#                    bus         32         57      0.663      0.439        0.5      0.388
#                  train         31         36      0.433      0.556      0.509      0.388
# ...

# %% [markdown]
# # deblurGANv2

# %%
deblurGANv2Bilateral_Filtered = update_yaml_paths(yaml_content,"deblurGANv2/Bilateral_Filtered")
with open("deblurGANv2Bilateral_Filtered.yaml", "w") as f:
    f.write(deblurGANv2Bilateral_Filtered)

metrics_blurred = model.val(
    data='deblurGANv2Bilateral_Filtered.yaml',
    imgsz=640,
    batch=16,
    cache=False,
    save_json=False
)
# Out:
# Ultralytics 8.3.67 🚀 Python-3.12.4 torch-2.5.1 CPU (Apple M1)
# val: Scanning /Users/ardaacikgoz/Desktop/Cs/ThirdYear/AIN434- PHOTOGRAPHY/Projec
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1000       7204      0.492      0.343      0.359      0.249
#                 person        546       2251      0.656      0.532      0.582      0.377
#                bicycle         33         78      0.584     0.0901      0.163     0.0922
#                    car         98        347        0.5      0.392      0.385      0.234
#             motorcycle         26         62      0.537      0.548      0.558      0.312
#               airplane         20         26      0.624      0.654      0.711      0.586
#                    bus         32         57      0.663      0.474      0.578      0.449
#                  train         31         36      0.527      0.583      0.609      0.441
# ...

# %%
deblurGANv2Defocus_Blurred = update_yaml_paths(yaml_content,"deblurGANv2/Defocus_Blurred")
with open("deblurGANv2Defocus_Blurred.yaml", "w") as f:
    f.write(deblurGANv2Defocus_Blurred)

metrics_blurred = model.val(
    data='deblurGANv2Defocus_Blurred.yaml',
    imgsz=640,
    batch=16,
    cache=False,
    save_json=False
)
# Out:
# Ultralytics 8.3.67 🚀 Python-3.12.4 torch-2.5.1 CPU (Apple M1)
# val: Scanning /Users/ardaacikgoz/Desktop/Cs/ThirdYear/AIN434- PHOTOGRAPHY/Projec
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1000       7204      0.543       0.39      0.426      0.297
#                 person        546       2251       0.72      0.557      0.624      0.414
#                bicycle         33         78      0.507      0.179      0.219       0.13
#                    car         98        347      0.575      0.352      0.386      0.232
#             motorcycle         26         62      0.642      0.548      0.639      0.383
#               airplane         20         26      0.732      0.615      0.718      0.562
#                    bus         32         57      0.719      0.526      0.582      0.461
#                  train         31         36      0.716      0.583      0.658      0.502
# ...

# %%
deblurGANv2Gaussian_Blurred = update_yaml_paths(yaml_content,"deblurGANv2/Gaussian_Blurred")
with open("deblurGANv2Gaussian_Blurred.yaml", "w") as f:
    f.write(deblurGANv2Gaussian_Blurred)

metrics_blurred = model.val(
    data='deblurGANv2Gaussian_Blurred.yaml',
    imgsz=640,
    batch=16,
    cache=False,
    save_json=False
)
# Out:
# Ultralytics 8.3.67 🚀 Python-3.12.4 torch-2.5.1 CPU (Apple M1)
# val: Scanning /Users/ardaacikgoz/Desktop/Cs/ThirdYear/AIN434- PHOTOGRAPHY/Projec
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1000       7204      0.467      0.264      0.283      0.191
#                 person        546       2251      0.644      0.429      0.486      0.307
#                bicycle         33         78      0.341     0.0513     0.0797     0.0463
#                    car         98        347      0.462      0.225      0.247      0.149
#             motorcycle         26         62      0.474      0.355      0.359      0.198
#               airplane         20         26      0.654        0.5      0.558      0.415
#                    bus         32         57      0.625      0.368      0.411      0.338
#                  train         31         36      0.625        0.5      0.542      0.382
# ...

# %%
deblurGANv2Low_Light_Blurred = update_yaml_paths(yaml_content,"deblurGANv2/Low_Light_Blurred")
with open("deblurGANv2Low_Light_Blurred.yaml", "w") as f:
    f.write(deblurGANv2Low_Light_Blurred)

metrics_blurred = model.val(
    data='deblurGANv2Low_Light_Blurred.yaml',
    imgsz=640,
    batch=16,
    cache=False,
    save_json=False
)
# Out:
# Ultralytics 8.3.67 🚀 Python-3.12.4 torch-2.5.1 CPU (Apple M1)
# val: Scanning /Users/ardaacikgoz/Desktop/Cs/ThirdYear/AIN434- PHOTOGRAPHY/Projec
#                  Class     Images  Instances      Box(P          R      mAP50  m

# %%
deblurGANv2Motion_Blurred = update_yaml_paths(yaml_content,"deblurGANv2/Motion_Blurred")
with open("deblurGANv2Motion_Blurred.yaml", "w") as f:
    f.write(deblurGANv2Motion_Blurred)

metrics_blurred = model.val(
    data='deblurGANv2Motion_Blurred.yaml',
    imgsz=640,
    batch=16,
    cache=False,
    save_json=False
)
